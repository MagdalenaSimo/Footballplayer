# %%
import pandas as pd
import numpy as np

table = pd.read_csv('data.csv')
table
# Out:
#        Unnamed: 0      ID                  Name  Age  \
# 0               0  158023              L. Messi   31
# 1               1   20801     Cristiano Ronaldo   33
# 2               2  190871             Neymar Jr   26
# 3               3  193080                De Gea   27
# 4               4  192985          K. De Bruyne   27
# 5               5  183277             E. Hazard   27
# 6               6  177003             L. Modrić   32
# 7               7  176580             L. Suárez   31
# 8               8  155862          Sergio Ramos   32
# 9               9  200389              J. Oblak   25
# 10             10  188545        R. Lewandowski   29
# 11             11  182521              T. Kroos   28
# 12             12  182493              D. Godín   32
# 13             13  168542           David Silva   32
# 14             14  215914              N. Kanté   27
# 15             15  211110             P. Dybala   24
# 16             16  202126               H. Kane   24
# ...

# %%
##Select only the footballplayer

name_footballplayer = table.Name
name_footballplayer
# Out:
# 0                    L. Messi
# 1           Cristiano Ronaldo
# 2                   Neymar Jr
# 3                      De Gea
# 4                K. De Bruyne
# 5                   E. Hazard
# 6                   L. Modrić
# 7                   L. Suárez
# 8                Sergio Ramos
# 9                    J. Oblak
# 10             R. Lewandowski
# 11                   T. Kroos
# 12                   D. Godín
# 13                David Silva
# 14                   N. Kanté
# 15                  P. Dybala
# 16                    H. Kane
# 17               A. Griezmann
# 18              M. ter Stegen
# 19                T. Courtois
# 20            Sergio Busquets
# 21                  E. Cavani
# 22                   M. Neuer
# 23                  S. Agüero
# 24               G. Chiellini
# 25                  K. Mbappé
# 26                   M. Salah
# 27                   Casemiro
# 28               J. Rodríguez
# 29                 L. Insigne
#                  ...
# ...

# %%
##How many footballplayer participated?
table.shape[0]
# Out:
# 18207

# %%
##What is the number of columns in dataset?
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
# Unnamed: 0                  18207 non-null int64
# ID                          18207 non-null int64
# Name                        18207 non-null object
# Age                         18207 non-null int64
# Photo                       18207 non-null object
# Nationality                 18207 non-null object
# Flag                        18207 non-null object
# Overall                     18207 non-null int64
# Potential                   18207 non-null int64
# Club                        17966 non-null object
# Club Logo                   18207 non-null object
# Value                       18207 non-null object
# Wage                        18207 non-null object
# Special                     18207 non-null int64
# Preferred Foot              18159 non-null object
# International Reputation    18159 non-null float64
# Weak Foot                   18159 non-null float64
# ...

# %%
##View only the columns Name, Nationality,CLub and assign them to dataframe called information

information = table[['Name','Nationality','Club']]
information
# Out:
#                        Name          Nationality                    Club
# 0                  L. Messi            Argentina            FC Barcelona
# 1         Cristiano Ronaldo             Portugal                Juventus
# 2                 Neymar Jr               Brazil     Paris Saint-Germain
# 3                    De Gea                Spain       Manchester United
# 4              K. De Bruyne              Belgium         Manchester City
# 5                 E. Hazard              Belgium                 Chelsea
# 6                 L. Modrić              Croatia             Real Madrid
# 7                 L. Suárez              Uruguay            FC Barcelona
# 8              Sergio Ramos                Spain             Real Madrid
# 9                  J. Oblak             Slovenia         Atlético Madrid
# 10           R. Lewandowski               Poland       FC Bayern München
# 11                 T. Kroos              Germany             Real Madrid
# ...

# %%
##Sort the Name by Club, then to Nationality

information.sort_values(['Club', 'Nationality'], ascending = False)
# Out:
#                     Name Nationality           Club
# 6421             R. Pich    Slovakia  Śląsk Wrocław
# 9488            D. Čotra      Serbia  Śląsk Wrocław
# 7910             Augusto    Portugal  Śląsk Wrocław
# 5067            M. Robak      Poland  Śląsk Wrocław
# 5678          P. Celeban      Poland  Śląsk Wrocław
# 7228            A. Piech      Poland  Śląsk Wrocław
# 7694          M. Chrapek      Poland  Śląsk Wrocław
# 9020             L. Broź      Poland  Śląsk Wrocław
# 9783        M. Cholewiak      Poland  Śląsk Wrocław
# 10524           W. Golla      Poland  Śląsk Wrocław
# 10549          J. Słowik      Poland  Śląsk Wrocław
# 13241       K. Dankowski      Poland  Śląsk Wrocław
# 14300         M. Pawelec      Poland  Śląsk Wrocław
# 14654     M. Pałaszewski      Poland  Śląsk Wrocław
# 15414      P. Kucharczyk      Poland  Śląsk Wrocław
# 15416          J. Wrąbel      Poland  Śląsk Wrocław
# 16601         M. Radecki      Poland  Śląsk Wrocław
# ...

# %%
##Calculate the mean Age in team
round(table['Age'].mean())
# Out:
# 25.0

# %%
##Filter Name that Age more than 25 year
table[table.Age > 25]
# Out:
#        Unnamed: 0      ID               Name  Age  \
# 0               0  158023           L. Messi   31
# 1               1   20801  Cristiano Ronaldo   33
# 2               2  190871          Neymar Jr   26
# 3               3  193080             De Gea   27
# 4               4  192985       K. De Bruyne   27
# 5               5  183277          E. Hazard   27
# 6               6  177003          L. Modrić   32
# 7               7  176580          L. Suárez   31
# 8               8  155862       Sergio Ramos   32
# 10             10  188545     R. Lewandowski   29
# 11             11  182521           T. Kroos   28
# 12             12  182493           D. Godín   32
# 13             13  168542        David Silva   32
# 14             14  215914           N. Kanté   27
# 17             17  194765       A. Griezmann   27
# 18             18  192448      M. ter Stegen   26
# 19             19  192119        T. Courtois   26
# 20             20  189511    Sergio Busquets   29
# ...

# %%
##Select the Name that starts with M
table[table.Name.str.startswith('M')]
# Out:
#        Unnamed: 0      ID               Name  Age  \
# 18             18  192448      M. ter Stegen   26
# 22             22  167495           M. Neuer   32
# 26             26  209331           M. Salah   26
# 34             34  178603         M. Hummels   29
# 35             35  176676            Marcelo   30
# 43             43  201399          M. Icardi   25
# 52             52  171877          M. Hamšík   30
# 63             63  199556        M. Verratti   25
# 68             68  188350            M. Reus   29
# 72             72  180206          M. Pjanić   28
# 73             73  177509         M. Benatia   31
# 74             74  176635            M. Özil   29
# 77             77  232363        M. Škriniar   23
# 79             79  220834      Marco Asensio   22
# 104           104  168609            Miranda   33
# 119           119  207865         Marquinhos   24
# 124           124  202556           M. Depay   24
# 128           128  198009           M. Perin   25
# ...

# %%
##Select the first 7 columns
table.iloc[: , 0:7]
# Out:
#        Unnamed: 0      ID                  Name  Age  \
# 0               0  158023              L. Messi   31
# 1               1   20801     Cristiano Ronaldo   33
# 2               2  190871             Neymar Jr   26
# 3               3  193080                De Gea   27
# 4               4  192985          K. De Bruyne   27
# 5               5  183277             E. Hazard   27
# 6               6  177003             L. Modrić   32
# 7               7  176580             L. Suárez   31
# 8               8  155862          Sergio Ramos   32
# 9               9  200389              J. Oblak   25
# 10             10  188545        R. Lewandowski   29
# 11             11  182521              T. Kroos   28
# 12             12  182493              D. Godín   32
# 13             13  168542           David Silva   32
# 14             14  215914              N. Kanté   27
# 15             15  211110             P. Dybala   24
# 16             16  202126               H. Kane   24
# ...

# %%
##Select all columns except the last 4

table.iloc[:, : -4]
# Out:
#        Unnamed: 0      ID                  Name  Age  \
# 0               0  158023              L. Messi   31
# 1               1   20801     Cristiano Ronaldo   33
# 2               2  190871             Neymar Jr   26
# 3               3  193080                De Gea   27
# 4               4  192985          K. De Bruyne   27
# 5               5  183277             E. Hazard   27
# 6               6  177003             L. Modrić   32
# 7               7  176580             L. Suárez   31
# 8               8  155862          Sergio Ramos   32
# 9               9  200389              J. Oblak   25
# 10             10  188545        R. Lewandowski   29
# 11             11  182521              T. Kroos   28
# 12             12  182493              D. Godín   32
# 13             13  168542           David Silva   32
# 14             14  215914              N. Kanté   27
# 15             15  211110             P. Dybala   24
# 16             16  202126               H. Kane   24
# ...
